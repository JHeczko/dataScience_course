# %% [markdown]
# # Tokenizers testing
# - it is example of workflow with my self written tokkenizers

# %%
from src import BasicTokenizer

import numpy
import pandas

from matplotlib import pyplot as plt

import tiktoken

# %% [markdown]
# # Load the text data

# %%
file_path = "./dataset/taylorswift.txt"
file = open(file=file_path, mode="r")
text = file.read()
print(text[:100])
# Out:
# Copy paste of the Wikipedia article on Taylor Swift, as of Feb 16, 2024.
# ---
#
# Main menu
#
# WikipediaTh

# %%
tokenizer = BasicTokenizer()
d = {"a":123,"b": 321, "c": 521, 'd': 672}

print(max(d.keys(), key=d.get))
# Out:
# d

# %%
tokenizer.train(text, vocab_size=20000)
# Out:
# (101, 32)
