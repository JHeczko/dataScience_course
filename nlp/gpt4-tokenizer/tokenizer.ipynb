# %% [markdown]
# # Tokenizers testing
# - it is example of workflow with my self written tokkenizers

# %%
from src import BasicTokenizer

import numpy
import pandas

from matplotlib import pyplot as plt

import tiktoken

# %% [markdown]
# # Load the text data

# %%
file_path = "./dataset/taylorswift.txt"
file = open(file=file_path, mode="r")
text = file.read()
print(text[:100])
# Out:
# Copy paste of the Wikipedia article on Taylor Swift, as of Feb 16, 2024.
# ---
#
# Main menu
#
# WikipediaTh

# %%
tokenizer = BasicTokenizer()

tokenizer.train(text=text, vocab_size=1000)
# Out:
# Merging (101, 32) to 257
# Merging (44, 32) to 258
# Merging (100, 32) to 259
# Merging (46, 32) to 260
# Merging (114, 32) to 261
# Merging (50, 48) to 262
# Merging (115, 32) to 263
# Merging (105, 110) to 264
# Merging (111, 110) to 265
# Merging (114, 105) to 266
# Merging (116, 32) to 267
# Merging (116, 104) to 268
# Merging (101, 259) to 269
# Merging (258, 262) to 270
# Merging (97, 110) to 271
# Merging (97, 114) to 272
# Merging (101, 261) to 273
# Merging (121, 32) to 274
# Merging (97, 108) to 275
# Merging (268, 257) to 276
# Merging (118, 269) to 277
# Merging (119, 105) to 278
# Merging (101, 114) to 279
# Merging (265, 32) to 280
# Merging (278, 102) to 281
# Merging (82, 101) to 282
# Merging (83, 281) to 283
# Merging (111, 261) to 284
# Merging (99, 104) to 285
# Merging (270, 49) to 286
# Merging (111, 109) to 287
# Merging (98, 273) to 288
# Merging (32, 276) to 289
# Merging (97, 121) to 290
# Merging (101, 110) to 291
# Merging (111, 114) to 292
# Merging (275, 32) to 293
# Merging (101, 109) to 294
# Merging (46, 10) to 295
# Merging (266, 101) to 296
# Merging (264, 103) to 297
# Merging (270, 50) to 298
# Merging (116, 105) to 299
# Merging (290, 108) to 300
# Merging (34, 260) to 301
# Merging (108, 108) to 302
# Merging (84, 300) to 303
# Merging (116, 296) to 304
# Merging (295, 32) to 305
# Merging (116, 111) to 306
# Merging (260, 282) to 307
# Merging (307, 304) to 308
# Merging (308, 277) to 309
# Merging (303, 284) to 310
# Merging (101, 115) to 311
# Merging (310, 283) to 312
# Merging (117, 115) to 313
# Merging (114, 287) to 314
# Merging (294, 288) to 315
# Merging (41, 260) to 316
# Merging (65, 114) to 317
# Merging (102, 314) to 318
# Merging (316, 34) to 319
# Merging (271, 259) to 320
# Merging (114, 101) to 321
# Merging (111, 117) to 322
# Merging (111, 266) to 323
# Merging (111, 102) to 324
# Merging (103, 264) to 325
# Merging (297, 32) to 326
# Merging (285, 105) to 327
# Merging (93, 32) to 328
# Merging (325, 293) to 329
# Merging (318, 289) to 330
# Merging (323, 329) to 331
# Merging (104, 257) to 332
# Merging (317, 327) to 333
# Merging (333, 277) to 334
# Merging (330, 331) to 335
# Merging (334, 335) to 336
# Merging (336, 280) to 337
# Merging (260, 337) to 338
# Merging (97, 32) to 339
# Merging (115, 116) to 340
# Merging (105, 99) to 341
# Merging (46, 91) to 342
# Merging (101, 99) to 343
# Merging (105, 302) to 344
# Merging (39, 263) to 345
# Merging (312, 267) to 346
# Merging (111, 118) to 347
# Merging (97, 116) to 348
# Merging (97, 263) to 349
# Merging (101, 263) to 350
# Merging (74, 117) to 351
# Merging (324, 32) to 352
# Merging (306, 32) to 353
# Merging (117, 109) to 354
# Merging (84, 332) to 355
# Merging (272, 100) to 356
# Merging (264, 32) to 357
# Merging (271, 32) to 358
# Merging (101, 108) to 359
# Merging (298, 51) to 360
# Merging (272, 274) to 361
# Merging (268, 32) to 362
# Merging (97, 109) to 363
# Merging (108, 274) to 364
# Merging (111, 112) to 365
# Merging (312, 116) to 366
# Merging (116, 114) to 367
# Merging (105, 115) to 368
# Merging (104, 273) to 369
# Merging (111, 32) to 370
# Merging (117, 361) to 371
# Merging (78, 347) to 372
# Merging (313, 341) to 373
# Merging (372, 315) to 374
# Merging (101, 119) to 375
# Merging (97, 267) to 376
# Merging (108, 32) to 377
# Merging (58, 32) to 378
# Merging (98, 111) to 379
# Merging (283, 267) to 380
# Merging (68, 343) to 381
# Merging (105, 116) to 382
# Merging (105, 103) to 383
# Merging (66, 344) to 384
# Merging (49, 48) to 385
# Merging (97, 115) to 386
# Merging (265, 103) to 387
# Merging (79, 99) to 388
# Merging (97, 299) to 389
# Merging (83, 116) to 390
# Merging (388, 306) to 391
# Merging (391, 288) to 392
# Merging (97, 99) to 393
# Merging (111, 119) to 394
# Merging (381, 315) to 395
# Merging (384, 379) to 396
# Merging (97, 100) to 397
# Merging (108, 101) to 398
# Merging (117, 114) to 399
# Merging (102, 284) to 400
# Merging (32, 40) to 401
# Merging (298, 50) to 402
# Merging (117, 103) to 403
# Merging (285, 32) to 404
# Merging (115, 267) to 405
# Merging (322, 110) to 406
# Merging (98, 354) to 407
# Merging (111, 108) to 408
# Merging (313, 267) to 409
# Merging (101, 98) to 410
# Merging (77, 97) to 411
# Merging (351, 364) to 412
# Merging (319, 346) to 413
# Merging (107, 32) to 414
# Merging (279, 115) to 415
# Merging (93, 91) to 416
# Merging (65, 403) to 417
# Merging (417, 409) to 418
# Merging (105, 100) to 419
# Merging (298, 49) to 420
# Merging (109, 101) to 421
# Merging (101, 112) to 422
# Merging (262, 49) to 423
# Merging (50, 51) to 424
# Merging (286, 50) to 425
# Merging (101, 272) to 426
# Merging (270, 262) to 427
# Merging (73, 110) to 428
# Merging (102, 105) to 429
# Merging (110, 257) to 430
# Merging (396, 356) to 431
# Merging (266, 116) to 432
# Merging (104, 105) to 433
# Merging (373, 32) to 434
# Merging (305, 34) to 435
# Merging (78, 375) to 436
# Merging (100, 105) to 437
# Merging (65, 112) to 438
# Merging (286, 57) to 439
# Merging (114, 111) to 440
# Merging (39, 32) to 441
# Merging (115, 258) to 442
# Merging (351, 430) to 443
# Merging (324, 289) to 444
# Merging (99, 292) to 445
# Merging (50, 49) to 446
# Merging (49, 57) to 447
# Merging (105, 109) to 448
# Merging (291, 32) to 449
# Merging (410, 114) to 450
# Merging (291, 116) to 451
# Merging (111, 302) to 452
# Merging (77, 272) to 453
# Merging (266, 99) to 454
# Merging (278, 362) to 455
# Merging (44, 91) to 456
# Merging (70, 450) to 457
# Merging (457, 371) to 458
# Merging (366, 345) to 459
# Merging (301, 431) to 460
# Merging (101, 97) to 461
# Merging (286, 54) to 462
# Merging (422, 116) to 463
# Merging (411, 274) to 464
# Merging (286, 53) to 465
# Merging (438, 266) to 466
# Merging (466, 377) to 467
# Merging (108, 257) to 468
# Merging (65, 119) to 469
# Merging (389, 265) to 470
# Merging (83, 463) to 471
# Merging (471, 315) to 472
# Merging (114, 97) to 473
# Merging (275, 407) to 474
# Merging (67, 104) to 475
# Merging (118, 257) to 476
# Merging (311, 267) to 477
# Merging (74, 271) to 478
# Merging (50, 50) to 479
# Merging (478, 371) to 480
# Merging (406, 367) to 481
# Merging (383, 104) to 482
# Merging (301, 355) to 483
# Merging (360, 305) to 484
# Merging (49, 51) to 485
# Merging (65, 108) to 486
# Merging (101, 116) to 487
# Merging (311, 115) to 488
# Merging (453, 404) to 489
# Merging (117, 116) to 490
# Merging (119, 432) to 491
# Merging (108, 111) to 492
# Merging (115, 387) to 493
# Merging (226, 128) to 494
# Merging (272, 259) to 495
# Merging (48, 32) to 496
# Merging (117, 108) to 497
# Merging (50, 52) to 498
# Merging (105, 263) to 499
# Merging (299, 99) to 500
# Merging (97, 103) to 501
# Merging (34, 32) to 502
# Merging (65, 110) to 503
# Merging (49, 56) to 504
# Merging (102, 292) to 505
# Merging (481, 274) to 506
# Merging (65, 421) to 507
# Merging (507, 454) to 508
# Merging (32, 84) to 509
# Merging (115, 297) to 510
# Merging (119, 349) to 511
# Merging (49, 50) to 512
# Merging (111, 99) to 513
# Merging (365, 32) to 514
# Merging (49, 55) to 515
# Merging (108, 105) to 516
# Merging (77, 434) to 517
# Merging (101, 258) to 518
# Merging (49, 52) to 519
# Merging (117, 110) to 520
# Merging (93, 10) to 521
# Merging (436, 32) to 522
# Merging (118, 105) to 523
# Merging (469, 356) to 524
# Merging (270, 48) to 525
# Merging (83, 332) to 526
# Merging (116, 279) to 527
# Merging (98, 274) to 528
# Merging (115, 332) to 529
# Merging (97, 105) to 530
# Merging (272, 116) to 531
# Merging (101, 302) to 532
# Merging (49, 49) to 533
# Merging (111, 116) to 534
# Merging (97, 98) to 535
# Merging (445, 100) to 536
# Merging (83, 112) to 537
# Merging (121, 258) to 538
# Merging (309, 412) to 539
# Merging (309, 418) to 540
# Merging (322, 114) to 541
# Merging (271, 100) to 542
# Merging (286, 55) to 543
# Merging (508, 358) to 544
# Merging (101, 101) to 545
# Merging (115, 117) to 546
# Merging (328, 320) to 547
# Merging (49, 53) to 548
# Merging (50, 54) to 549
# Merging (111, 103) to 550
# Merging (101, 118) to 551
# Merging (50, 57) to 552
# Merging (420, 305) to 553
# Merging (87, 105) to 554
# Merging (32, 77) to 555
# Merging (321, 99) to 556
# Merging (83, 387) to 557
# Merging (50, 53) to 558
# Merging (50, 55) to 559
# Merging (262, 48) to 560
# Merging (390, 265) to 561
# Merging (101, 105) to 562
# Merging (309, 395) to 563
# Merging (291, 267) to 564
# Merging (402, 305) to 565
# Merging (322, 261) to 566
# Merging (114, 405) to 567
# Merging (111, 100) to 568
# Merging (40, 374) to 569
# Merging (105, 265) to 570
# Merging (32, 320) to 571
# Merging (115, 115) to 572
# Merging (82, 452) to 573
# Merging (460, 338) to 574
# Merging (419, 101) to 575
# Merging (291, 110) to 576
# Merging (101, 120) to 577
# Merging (279, 258) to 578
# Merging (348, 269) to 579
# Merging (505, 109) to 580
# Merging (271, 99) to 581
# Merging (573, 326) to 582
# Merging (582, 561) to 583
# Merging (51, 48) to 584
# Merging (309, 374) to 585
# Merging (104, 97) to 586
# Merging (34, 258) to 587
# Merging (99, 265) to 588
# Merging (112, 32) to 589
# Merging (97, 264) to 590
# Merging (101, 100) to 591
# Merging (486, 407) to 592
# Merging (272, 299) to 593
# Merging (71, 114) to 594
# Merging (105, 280) to 595
# Merging (342, 53) to 596
# Merging (84, 448) to 597
# Merging (360, 319) to 598
# Merging (49, 54) to 599
# Merging (389, 280) to 600
# Merging (291, 100) to 601
# Merging (105, 340) to 602
# Merging (283, 116) to 603
# Merging (112, 108) to 604
# Merging (311, 116) to 605
# Merging (309, 458) to 606
# Merging (309, 392) to 607
# Merging (99, 287) to 608
# Merging (110, 32) to 609
# Merging (265, 257) to 610
# Merging (299, 265) to 611
# Merging (117, 99) to 612
# Merging (105, 271) to 613
# Merging (279, 263) to 614
# Merging (298, 52) to 615
# Merging (396, 495) to 616
# Merging (339, 40) to 617
# Merging (342, 51) to 618
# Merging (264, 289) to 619
# Merging (50, 56) to 620
# Merging (394, 32) to 621
# Merging (342, 52) to 622
# Merging (309, 467) to 623
# Merging (494, 147) to 624
# Merging (311, 263) to 625
# Merging (73, 263) to 626
# Merging (104, 349) to 627
# Merging (109, 274) to 628
# Merging (268, 376) to 629
# Merging (258, 74) to 630
# Merging (286, 51) to 631
# Merging (111, 267) to 632
# Merging (116, 263) to 633
# Merging (444, 89) to 634
# Merging (461, 261) to 635
# Merging (583, 101) to 636
# Merging (328, 526) to 637
# Merging (328, 380) to 638
# Merging (115, 112) to 639
# Merging (108, 117) to 640
# Merging (112, 112) to 641
# Merging (87, 104) to 642
# Merging (280, 276) to 643
# Merging (428, 32) to 644
# Merging (286, 52) to 645
# Merging (274, 40) to 646
# Merging (109, 434) to 647
# Merging (429, 567) to 648
# Merging (116, 273) to 649
# Merging (83, 104) to 650
# Merging (292, 108) to 651
# Merging (257, 40) to 652
# Merging (301, 636) to 653
# Merging (76, 105) to 654
# Merging (262, 424) to 655
# Merging (97, 107) to 656
# Merging (112, 104) to 657
# Merging (112, 114) to 658
# Merging (386, 104) to 659
# Merging (523, 375) to 660
# Merging (286, 56) to 661
# Merging (109, 111) to 662
# Merging (282, 536) to 663
# Merging (318, 32) to 664
# Merging (105, 114) to 665
# Merging (84, 104) to 666
# Merging (435, 346) to 667
# Merging (301, 67) to 668
# Merging (291, 99) to 669
# Merging (309, 464) to 670
# Merging (85, 83) to 671
# Merging (72, 273) to 672
# Merging (258, 320) to 673
# Merging (398, 386) to 674
# Merging (65, 302) to 675
# Merging (109, 271) to 676
# Merging (554, 362) to 677
# Merging (427, 305) to 678
# Merging (317, 299) to 679
# Merging (99, 506) to 680
# Merging (603, 345) to 681
# Merging (109, 344) to 682
# Merging (338, 374) to 683
# Merging (282, 112) to 684
# Merging (474, 32) to 685
# Merging (109, 373) to 686
# Merging (48, 48) to 687
# Merging (425, 305) to 688
# Merging (575, 370) to 689
# Merging (97, 261) to 690
# Merging (269, 276) to 691
# Merging (98, 101) to 692
# Merging (347, 273) to 693
# Merging (263, 40) to 694
# Merging (115, 104) to 695
# Merging (522, 89) to 696
# Merging (696, 292) to 697
# Merging (99, 266) to 698
# Merging (286, 48) to 699
# Merging (338, 395) to 700
# Merging (105, 108) to 701
# Merging (118, 344) to 702
# Merging (119, 433) to 703
# Merging (268, 273) to 704
# Merging (112, 279) to 705
# Merging (416, 51) to 706
# Merging (309, 472) to 707
# Merging (72, 632) to 708
# Merging (102, 102) to 709
# Merging (32, 83) to 710
# Merging (545, 107) to 711
# Merging (113, 117) to 712
# Merging (309, 443) to 713
# Merging (402, 319) to 714
# Merging (41, 10) to 715
# Merging (493, 491) to 716
# Merging (98, 108) to 717
# Merging (98, 343) to 718
# Merging (321, 674) to 719
# Merging (89, 322) to 720
# Merging (292, 257) to 721
# Merging (69, 114) to 722
# Merging (119, 104) to 723
# Merging (557, 491) to 724
# Merging (279, 257) to 725
# Merging (301, 86) to 726
# Merging (56, 57) to 727
# Merging (269, 528) to 728
# Merging (272, 267) to 729
# Merging (111, 115) to 730
# Merging (67, 506) to 731
# Merging (525, 57) to 732
# Merging (67, 265) to 733
# Merging (77, 373) to 734
# Merging (321, 363) to 735
# Merging (110, 354) to 736
# Merging (98, 279) to 737
# Merging (262, 262) to 738
# Merging (71, 321) to 739
# Merging (264, 99) to 740
# Merging (703, 404) to 741
# Merging (263, 352) to 742
# Merging (77, 84) to 743
# Merging (49, 32) to 744
# Merging (97, 340) to 745
# Merging (78, 659) to 746
# Merging (746, 702) to 747
# Merging (269, 369) to 748
# Merging (112, 514) to 749
# Merging (258, 380) to 750
# Merging (594, 363) to 751
# Merging (97, 118) to 752
# Merging (275, 108) to 753
# Merging (368, 267) to 754
# Merging (338, 392) to 755
# Merging (69, 110) to 756
# Merging (65, 32) to 757
# Merging (111, 111) to 758
# Merging (303, 292) to 759
# Merging (363, 257) to 760
# Merging (378, 355) to 761
# Merging (299, 109) to 762
# Merging (97, 274) to 763
# Merging (101, 274) to 764
# Merging (105, 118) to 765
# Merging (71, 117) to 766
# Merging (51, 49) to 767
# Merging (436, 115) to 768
# Merging (116, 399) to 769
# Merging (447, 727) to 770
# Merging (275, 257) to 771
# Merging (87, 651) to 772
# Merging (751, 628) to 773
# Merging (445, 259) to 774
# Merging (349, 339) to 775
# Merging (475, 266) to 776
# Merging (322, 267) to 777
# Merging (100, 258) to 778
# Merging (66, 477) to 779
# Merging (462, 305) to 780
# Merging (338, 443) to 781
# Merging (473, 657) to 782
# Merging (97, 258) to 783
# Merging (376, 276) to 784
# Merging (271, 105) to 785
# Merging (313, 367) to 786
# Merging (69, 118) to 787
# Merging (107, 257) to 788
# Merging (722, 349) to 789
# Merging (59, 32) to 790
# Merging (74, 111) to 791
# Merging (286, 49) to 792
# Merging (101, 301) to 793
# Merging (112, 101) to 794
# Merging (121, 108) to 795
# Merging (66, 383) to 796
# Merging (116, 258) to 797
# Merging (84, 566) to 798
# Merging (109, 32) to 799
# Merging (605, 45) to 800
# Merging (275, 377) to 801
# Merging (492, 98) to 802
# Merging (634, 635) to 803
# Merging (105, 421) to 804
# Merging (117, 293) to 805
# Merging (368, 104) to 806
# Merging (385, 48) to 807
# Merging (101, 267) to 808
# Merging (264, 110) to 809
# Merging (101, 103) to 810
# Merging (459, 39) to 811
# Merging (366, 258) to 812
# Merging (348, 257) to 813
# Merging (65, 99) to 814
# Merging (311, 258) to 815
# Merging (393, 414) to 816
# Merging (684, 490) to 817
# Merging (759, 345) to 818
# Merging (99, 279) to 819
# Merging (257, 352) to 820
# Merging (269, 353) to 821
# Merging (78, 111) to 822
# Merging (416, 53) to 823
# Merging (513, 105) to 824
# Merging (112, 440) to 825
# Merging (517, 524) to 826
# Merging (119, 287) to 827
# Merging (593, 340) to 828
# Merging (87, 344) to 829
# Merging (117, 261) to 830
# Merging (294, 771) to 831
# Merging (70, 292) to 832
# Merging (592, 32) to 833
# Merging (111, 313) to 834
# Merging (272, 257) to 835
# Merging (101, 345) to 836
# Merging (297, 289) to 837
# Merging (271, 110) to 838
# Merging (309, 480) to 839
# Merging (86, 689) to 840
# Merging (117, 717) to 841
# Merging (397, 105) to 842
# Merging (77, 101) to 843
# Merging (263, 320) to 844
# Merging (682, 595) to 845
# Merging (382, 274) to 846
# Merging (705, 580) to 847
# Merging (103, 104) to 848
# Merging (108, 121) to 849
# Merging (662, 405) to 850
# Merging (44, 687) to 851
# Merging (87, 711) to 852
# Merging (116, 101) to 853
# Merging (338, 412) to 854
# Merging (338, 472) to 855
# Merging (338, 418) to 856
# Merging (115, 301) to 857
# Merging (597, 311) to 858
# Merging (271, 103) to 859
# Merging (375, 32) to 860
# Merging (341, 32) to 861
# Merging (461, 414) to 862
# Merging (397, 257) to 863
# Merging (272, 107) to 864
# Merging (306, 289) to 865
# Merging (115, 370) to 866
# Merging (73, 32) to 867
# Merging (101, 102) to 868
# Merging (393, 107) to 869
# Merging (469, 495) to 870
# Merging (287, 264) to 871
# Merging (85, 110) to 872
# Merging (415, 570) to 873
# Merging (338, 480) to 874
# Merging (360, 413) to 875
# Merging (439, 305) to 876
# Merging (576, 488) to 877
# Merging (426, 108) to 878
# Merging (382, 263) to 879
# Merging (121, 110) to 880
# Merging (97, 117) to 881
# Merging (419, 110) to 882
# Merging (679, 405) to 883
# Merging (269, 280) to 884
# Merging (697, 414) to 885
# Merging (593, 405) to 886
# Merging (698, 500) to 887
# Merging (52, 328) to 888
# Merging (65, 572) to 889
# Merging (97, 104) to 890
# Merging (338, 464) to 891
# Merging (822, 260) to 892
# Merging (676, 258) to 893
# Merging (101, 348) to 894
# Merging (383, 110) to 895
# Merging (41, 32) to 896
# Merging (111, 258) to 897
# Merging (70, 878) to 898
# Merging (320, 34) to 899
# Merging (102, 649) to 900
# Merging (104, 482) to 901
# Merging (276, 648) to 902
# Merging (53, 328) to 903
# Merging (100, 265) to 904
# Merging (103, 477) to 905
# Merging (117, 267) to 906
# Merging (103, 291) to 907
# Merging (291, 299) to 908
# Merging (482, 116) to 909
# Merging (116, 121) to 910
# Merging (86, 873) to 911
# Merging (439, 319) to 912
# Merging (420, 319) to 913
# Merging (321, 257) to 914
# Merging (115, 10) to 915
# Merging (84, 541) to 916
# Merging (100, 612) to 917
# Merging (40, 423) to 918
# Merging (510, 468) to 919
# Merging (416, 52) to 920
# Merging (80, 101) to 921
# Merging (456, 53) to 922
# Merging (70, 105) to 923
# Merging (97, 497) to 924
# Merging (97, 296) to 925
# Merging (366, 378) to 926
# Merging (437, 339) to 927
# Merging (114, 311) to 928
# Merging (586, 476) to 929
# Merging (100, 311) to 930
# Merging (474, 263) to 931
# Merging (720, 32) to 932
# Merging (97, 112) to 933
# Merging (537, 862) to 934
# Merging (934, 78) to 935
# Merging (357, 423) to 936
# Merging (832, 98) to 937
# Merging (77, 111) to 938
# Merging (640, 100) to 939
# Merging (341, 107) to 940
# Merging (328, 644) to 941
# Merging (747, 257) to 942
# Merging (111, 45) to 943
# Merging (82, 111) to 944
# Merging (406, 100) to 945
# Merging (525, 56) to 946
# Merging (400, 276) to 947
# Merging (851, 496) to 948
# Merging (84, 114) to 949
# Merging (818, 911) to 950
# Merging (77, 99) to 951
# Merging (624, 32) to 952
# Merging (550, 782) to 953
# Merging (264, 100) to 954
# Merging (112, 365) to 955
# Merging (97, 259) to 956
# Merging (108, 350) to 957
# Merging (385, 496) to 958
# Merging (116, 326) to 959
# Merging (587, 34) to 960
# Merging (66, 492) to 961
# Merging (279, 109) to 962
# Merging (321, 536) to 963
# Merging (71, 802) to 964
# Merging (740, 939) to 965
# Merging (359, 112) to 966
# Merging (456, 52) to 967
# Merging (530, 259) to 968
# Merging (119, 280) to 969
# Merging (889, 824) to 970
# Merging (503, 110) to 971
# Merging (429, 359) to 972
# Merging (292, 274) to 973
# Merging (110, 860) to 974
# Merging (386, 115) to 975
# Merging (475, 729) to 976
# Merging (32, 768) to 977
# Merging (462, 540) to 978
# Merging (366, 301) to 979
# Merging (72, 621) to 980
# Merging (83, 297) to 981
# Merging (264, 257) to 982
# Merging (340, 735) to 983
# Merging (77, 882) to 984
# Merging (97, 119) to 985
# Merging (440, 572) to 986
# Merging (292, 101) to 987
# Merging (342, 54) to 988
# Merging (67, 272) to 989
# Merging (121, 426) to 990
# Merging (263, 353) to 991
# Merging (278, 268) to 992
# Merging (494, 148) to 993
# Merging (116, 590) to 994
# Merging (84, 804) to 995
# Merging (473, 368) to 996
# Merging (97, 266) to 997
# Merging (338, 489) to 998
# Merging (40, 392) to 999
# Merging (401, 392) to 1000
